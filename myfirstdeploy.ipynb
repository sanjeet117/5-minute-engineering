# %%
import streamlit as st
import pandas as pd
import numpy as np
import time

 
st.title("5 Minutes Engineering(Title)")
st.header("5 Minutes Engineering(Header)")
st.subheader("5 Minutes Engineering(Sub-Header)")
st.write("5 Minutes Engineering(Text)")
st.markdown("5 Minutes Engineering(Markdown)")
st.caption("5 Minutes Engineering(Caption)")

st.image("xyz.jpg")
st.audio("speech.wav")
st.video("abc.mkv")

st.checkbox('checkbox')
st.button('Click button')
st.radio('Pick your city',['Pune','Mumbai','delhi','surat'])
st.selectbox('Pick your city',['Pune','Mumbai','delhi','surat'])
st.multiselect('Pick favourite sports',['cricket', 'football', 'basketball'])
st.select_slider('Give a Remark', ['Bad', 'Good', 'Excellent'])
st.slider('Your Marks', 0,100)

on = st.toggle("Activate feature")
if on:
    st.write("Feature activated!")

number = st.number_input("Insert a number")
st.write("The current number is ", number)

d = st.date_input("When's your birthday", value=None)
st.write("Your birthday is:", d)

t = st.time_input("Set an alarm for", value=None)
st.write("Alarm is set for", t)

st.number_input('Enter your marks', 0,100)
st.text_input('Enter Text')
st.date_input('Exam date')
st.time_input('Exam time')
st.text_area('Description')
st.file_uploader('Upload File')
st.color_picker('Choose a color')

st.success("Success")
st.error("Error")
st.warning("Warning")
st.info("Information")
st.exception(RuntimeError("RuntimeError exception"))

st.sidebar.title("5 Minutes Engineering")
st.sidebar.image("xyz.jpg")

df = pd.DataFrame(np.random.randn(50, 20), columns=("col %d" % i for i in range(20)))
st.dataframe(df)


df = pd.DataFrame(
    np.random.randn(10, 5), columns=("col %d" % i for i in range(5))
)
st.table(df)

col1, col2, col3 = st.columns(3)
col1.metric("Temperature", "70 °F", "1.2 °F")
col2.metric("Wind", "9 mph", "-8%")
col3.metric("Humidity", "86%", "4%")

prompt = st.chat_input("Say something")
if prompt:
    st.write(f"User has sent the following prompt: {prompt}")
    
    

with st.status("Step 1"):
    st.write("Step 2")
    time.sleep(1)
    st.write("Step 3")
    time.sleep(1)
    st.write("Step 4")
    time.sleep(1)
st.button("Rerun")


chart_data = pd.DataFrame(np.random.randn(20, 3), columns=["a", "b", "c"])
st.area_chart(chart_data)

chart_data = pd.DataFrame(np.random.randn(20, 3), columns=["a", "b", "c"])
st.bar_chart(chart_data)

chart_data = pd.DataFrame(np.random.randn(20, 3), columns=["a", "b", "c"])
st.line_chart(chart_data)

df = pd.DataFrame({
    "lat" : [123],
    "lon" : [456]
})
st.map(df)

chart_data = pd.DataFrame(np.random.randn(20, 3), columns=["a", "b", "c"])
st.scatter_chart(chart_data)

with st.chat_message("user"):
    st.write("Hello ji")
# Out:
# 2025-06-28 19:18:23.763
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\Admin\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\streamlit\elements\image.py:375, in image_to_url(image, width, clamp, channels, output_format, image_id)
#     374 try:
# --> 375     with open(image, "rb") as f:
#     376         image_data = f.read()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'xyz.jpg'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 14
#      11 st.markdown("5 Minutes Engineering(Markdown)")
#      12 st.caption("5 Minutes Engineering(Caption)")
# ---> 14 st.image("xyz.jpg")
#      15 st.audio("speech.wav")
#      16 st.video("abc.mkv")
#
# File ~\anaconda3\Lib\site-packages\streamlit\runtime\metrics_util.py:396, in gather_metrics.<locals>.wrapped_func(*args, **kwargs)
#     394         _LOGGER.debug("Failed to collect command telemetry", exc_info=ex)
#     395 try:
# --> 396     result = non_optional_func(*args, **kwargs)
#     397 except RerunException as ex:
#     398     # Duplicated from below, because static analysis tools get confused
#     399     # by deferring the rethrow.
#     400     if tracking_activated and command_telemetry:
#
# File ~\anaconda3\Lib\site-packages\streamlit\elements\image.py:165, in ImageMixin.image(self, image, caption, width, use_column_width, clamp, channels, output_format)
#     162     raise StreamlitAPIException("Image width must be positive.")
#     164 image_list_proto = ImageListProto()
# --> 165 marshall_images(
#     166     self.dg._get_delta_path_str(),
#     167     image,
#     168     caption,
#     169     width,
#     170     image_list_proto,
#     171     clamp,
#     172     channels,
#     173     output_format,
#     174 )
#     175 return self.dg._enqueue("imgs", image_list_proto)
#
# File ~\anaconda3\Lib\site-packages\streamlit\elements\image.py:534, in marshall_images(coordinates, image, caption, width, proto_imgs, clamp, channels, output_format)
#     530 # We use the index of the image in the input image list to identify this image inside
#     531 # MediaFileManager. For this, we just add the index to the image's "coordinates".
#     532 image_id = "%s-%i" % (coordinates, coord_suffix)
# --> 534 proto_img.url = image_to_url(
#     535     image, width, clamp, channels, output_format, image_id
#     536 )
#
# File ~\anaconda3\Lib\site-packages\streamlit\elements\image.py:385, in image_to_url(image, width, clamp, channels, output_format, image_id)
#     382 if mimetype is None:
#     383     mimetype = "application/octet-stream"
# --> 385 url = runtime.get_instance().media_file_mgr.add(image, mimetype, image_id)
#     386 caching.save_media_data(image, mimetype, image_id)
#     387 return url
#
# File ~\anaconda3\Lib\site-packages\streamlit\runtime\__init__.py:26, in get_instance()
#      22 def get_instance() -> Runtime:
#      23     """Return the singleton Runtime instance. Raise an Error if the
#      24     Runtime hasn't been created yet.
#      25     """
# ---> 26     return Runtime.instance()
#
# File ~\anaconda3\Lib\site-packages\streamlit\runtime\runtime.py:152, in Runtime.instance(cls)
#     148 """Return the singleton Runtime instance. Raise an Error if the
#     149 Runtime hasn't been created yet.
#     150 """
#     151 if cls._instance is None:
# --> 152     raise RuntimeError("Runtime hasn't been created!")
#     153 return cls._instance
#
# RuntimeError: Runtime hasn't been created!
